# %% [markdown]
# # Notebook
#
# Created on 2026-06-12.

# %%
import numpy as np
import matplotlib.pyplot as plt

# X.min()/X.max() return true scalars; the built-in min(X)/max(X) fail
# on a 2D array because each "row" is itself an array.
X_grid = np.arange(X.min(), X.max(), 0.01).reshape(-1, 1)

plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X_grid, regressor.predict(X_grid), color='green', label="Random Forest Prediction")
plt.title("Random Forest Regression")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.legend()
plt.show()
